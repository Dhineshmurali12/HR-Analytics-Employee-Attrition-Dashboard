# %% [markdown]
# # HR Analytics Employee Attrition Dashboard
#
# # Day 2 – Data Cleaning & Feature Engineering
#
# ## Objective
#
# The objective of this notebook is to assess data quality, identify unnecessary features, classify variables, and prepare the dataset for exploratory analysis.
#
# ### Tasks
#
# - Load the HR dataset
# - Examine feature uniqueness
# - Identify constant columns
# - Identify identifier columns
# - Classify numerical and categorical features
# - Save the cleaned dataset

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/WA_Fn-UseC_-HR-Employee-Attrition.csv")

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Feature Uniqueness
#
# Understanding the number of unique values helps identify:
#
# - Constant columns
# - Identifier columns
# - Binary variables
# - Categorical variables

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# Age: 43
# Attrition: 2
# BusinessTravel: 3
# DailyRate: 886
# Department: 3
# DistanceFromHome: 29
# Education: 5
# EducationField: 6
# EmployeeCount: 1
# EmployeeNumber: 1470
# EnvironmentSatisfaction: 4
# Gender: 2
# HourlyRate: 71
# JobInvolvement: 4
# JobLevel: 5
# JobRole: 9
# JobSatisfaction: 4
# MaritalStatus: 3
# MonthlyIncome: 1349
# MonthlyRate: 1427
# NumCompaniesWorked: 10
# Over18: 1
# OverTime: 2
# PercentSalaryHike: 15
# PerformanceRating: 2
# RelationshipSatisfaction: 4
# StandardHours: 1
# StockOptionLevel: 4
# TotalWorkingYears: 40
# TrainingTimesLastYear: 7
# WorkLifeBalance: 4
# YearsAtCompany: 37
# YearsInCurrentRole: 19
# YearsSinceLastPromotion: 16
# YearsWithCurrManager: 18

# %% [markdown]
# # Data Dictionary
#
# | Column | Description | Category |
# |---------|-------------|----------|

# %% [markdown]
# # Feature Categories
#
# ## Employee Information
# - Age
# - Gender
# - MaritalStatus
# - Education
# - EducationField
#
# ## Job Information
# - Department
# - JobRole
# - JobLevel
# - BusinessTravel
# - DistanceFromHome
#
# ## Compensation
# - DailyRate
# - HourlyRate
# - MonthlyIncome
# - MonthlyRate
# - StockOptionLevel
#
# ## Performance & Experience
# - PerformanceRating
# - PercentSalaryHike
# - TotalWorkingYears
# - TrainingTimesLastYear
# - YearsAtCompany
# - YearsInCurrentRole
# - YearsSinceLastPromotion
# - YearsWithCurrManager
#
# ## Satisfaction Metrics
# - EnvironmentSatisfaction
# - JobInvolvement
# - JobSatisfaction
# - RelationshipSatisfaction
# - WorkLifeBalance
#
# ## Target Variable
# - Attrition
#
# ## Other
# - EmployeeNumber
# - EmployeeCount
# - Over18
# - StandardHours

# %% [markdown]
# ## Constant Columns
#
# Columns containing only one unique value do not provide useful information for analysis and can be excluded from modeling or visualization.

# %%
for col in df.columns:
    if df[col].nunique() == 1:
        print(col)
# Out:
# EmployeeCount
# Over18
# StandardHours

# %% [markdown]
# ## Identifier Column
#
# EmployeeNumber is a unique identifier assigned to each employee. It is useful for identification but should not be used for analytical modeling or visualization.

# %%
print(df["EmployeeNumber"].head())

print(df["EmployeeNumber"].nunique())
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    7
# Name: EmployeeNumber, dtype: int64
# 1470

# %% [markdown]
# ## Columns Excluded from Analysis
#
# | Column | Reason |
# |---------|--------|
# | EmployeeCount | Constant value |
# | Over18 | Constant value |
# | StandardHours | Constant value |
# | EmployeeNumber | Unique identifier |

# %% [markdown]
# ## Feature Classification
#
# Separating numerical and categorical variables helps determine the appropriate analytical and visualization techniques.

# %%
categorical_cols = df.select_dtypes(
    include="object"
).columns.tolist()

numerical_cols = df.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Categorical Columns")
print(categorical_cols)

print()

print("Numerical Columns")
print(numerical_cols)
# Out:
# Categorical Columns
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
#
# Numerical Columns
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# ## Save Clean Dataset
#
# The validated dataset is saved for use in subsequent notebooks.

# %%
df.to_csv(
    "../data/hr_cleaned.csv",
    index=False
)

# %%
import os

os.path.exists("../data/hr_cleaned.csv")
# Out:
# True

# %% [markdown]
# # Day 2 Summary
#
# ### Key Findings
#
# - No missing values detected
# - No duplicate records found
# - Three constant columns identified
# - One identifier column identified
# - Features successfully classified
# - Clean dataset exported for exploratory analysis
#
# ### Next Steps
#
# The cleaned dataset will be used for exploratory data analysis and business insights in the next notebook.
